# %%
import serial
import time
import pyautogui
from collections import deque
import cv2
import numpy as np

# %%
serial_deque = deque(['P', '`', 'd', '1', '`', 'P', '`', 'r', '1', '`', 'p', '`', 'r', '5', '`', 'P', '`', 'r', '14', '`', 'd', '1', '`', 'P', '`', 'l', '14', '`', 'p', '`', 'l', '5', '`', 'P', '`', 'l', '1', '`', 'd', '1', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '5', '`', 'p', '`', 'r', '4', '`', 'P', '`', 'r', '7', '`', 'd', '1', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '4', '`', 'P', '`', 'l', '5', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '5', '`', 'p', '`', 'r', '4', '`', 'P', '`', 'r', '7', '`', 'd', '1', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '4', '`', 'P', '`', 'l', '5', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '5', '`', 'p', '`', 'r', '4', '`', 'P', '`', 'r', '7', '`', 'd', '1', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '4', '`', 'P', '`', 'l', '5', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '5', '`', 'p', '`', 'r', '4', '`', 'P', '`', 'r', '7', '`', 'd', '1', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '4', '`', 'P', '`', 'l', '5', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '5', '`', 'p', '`', 'r', '4', '`', 'P', '`', 'r', '7', '`', 'd', '1', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '4', '`', 'P', '`', 'l', '5', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '1', '`', 'p', '`', 'r', '5', '`', 'P', '`', 'r', '14', '`', 'd', '1', '`', 'P', '`', 'l', '14', '`', 'p', '`', 'l', '5', '`', 'P', '`', 'l', '1', '`', 'd', '3', '`', 'P', '`', 'r', '1', '`', 'p', '`', 'r', '4', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '4', '`', 'P', '`', 'r', '8', '`', 'd', '1', '`', 'P', '`', 'l', '9', '`', 'p', '`', 'l', '2', '`', 'P', '`', 'l', '5', '`', 'p', '`', 'l', '2', '`', 'P', '`', 'l', '2', '`', 'd', '1', '`', 'P', '`', 'r', '2', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '5', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '9', '`', 'd', '1', '`', 'P', '`', 'l', '9', '`', 'p', '`', 'l', '2', '`', 'P', '`', 'l', '5', '`', 'p', '`', 'l', '2', '`', 'P', '`', 'l', '2', '`', 'd', '1', '`', 'P', '`', 'r', '2', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '5', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '9', '`', 'd', '1', '`', 'P', '`', 'l', '10', '`', 'p', '`', 'l', '7', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '7', '`', 'P', '`', 'r', '10', '`', 'd', '5', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '9', '`', 'p', '`', 'l', '3', '`', 'd', '1', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '8', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '6', '`', 'd', '1', '`', 'P', '`', 'l', '5', '`', 'p', '`', 'l', '5', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '6', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '7', '`', 'd', '1', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '6', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '6', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '7', '`', 'd', '1', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '9', '`', 'p', '`', 'l', '3', '`', 'd', '1', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '9', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '7', '`', 'd', '1', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '9', '`', 'p', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '6', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '6', '`', 'd', '1', '`', 'P', '`', 'l', '15', '`', 'p', '`', 'l', '2', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '1', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '9', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '7', '`', 'd', '1', '`', 'P', '`', 'l', '6', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '8', '`', 'p', '`', 'l', '2', '`', 'P', '`', 'l', '1', '`', 'd', '1', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '5', '`', 'p', '`', 'r', '5', '`', 'P', '`', 'r', '5', '`', 'd', '1', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '2', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '2', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '9', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '7', '`', 'd', '1', '`', 'P', '`', 'l', '7', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '8', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '2', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '9', '`', 'p', '`', 'r', '1', '`', 'P', '`', 'r', '7', '`', 'd', '1', '`', 'P', '`', 'l', '2', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '4', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '12', '`', 'd', '1', '`', 'P', '`', 'r', '12', '`', 'p', '`', 'r', '6', '`', 'P', '`', 'r', '2', '`', 'd', '1', '`', 'P', '`', 'l', '2', '`', 'p', '`', 'l', '1', '`', 'P', '`', 'l', '17', '`', 'd', '2', '`'])

# %%
def interact_ser(_str, _ard):
    _ard.write(_str.encode())
    tmp = _ard.readline()
    print(tmp.decode())
    
if __name__ == "__main__":
    port = 'COM4'  # 변동가능
    ard = serial.Serial(port, 9600)
    time.sleep(3)

    for i in serial_deque:
        if list(pyautogui.position()) != [0, 0]:
            interact_ser(i, ard)

    ard.close()
