# %%
import serial
import time
import pyautogui
from collections import deque
import cv2
import numpy as np

# %%
serial_deque = deque(['p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'd', '1', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'd', '1', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'd', '1', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'd', '1', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'd', '1', '`', 'P', '`', 'r', '6', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '6', '`', 'd', '1', '`', 'P', '`', 'l', '6', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '6', '`', 'd', '1', '`', 'P', '`', 'r', '6', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '6', '`', 'd', '1', '`', 'P', '`', 'l', '6', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '6', '`', 'd', '1', '`', 'P', '`', 'r', '6', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '6', '`', 'd', '1', '`', 'P', '`', 'l', '6', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '6', '`', 'd', '1', '`', 'P', '`', 'r', '9', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '9', '`', 'd', '1', '`', 'P', '`', 'l', '9', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '9', '`', 'd', '1', '`', 'P', '`', 'r', '9', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '9', '`', 'd', '1', '`', 'P', '`', 'l', '1', '`', 'p', '`', 'l', '2', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '6', '`', 'd', '1', '`', 'P', '`', 'r', '6', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '1', '`', 'd', '1', '`', 'P', '`', 'l', '1', '`', 'p', '`', 'l', '2', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '6', '`', 'd', '1', '`', 'P', '`', 'r', '6', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '1', '`', 'd', '1', '`', 'P', '`', 'l', '1', '`', 'p', '`', 'l', '2', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '6', '`', 'd', '1', '`', 'P', '`', 'r', '6', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '1', '`', 'd', '1', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '9', '`', 'd', '1', '`', 'P', '`', 'r', '9', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'd', '1', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '9', '`', 'd', '1', '`', 'P', '`', 'r', '6', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '1', '`', 'd', '1', '`', 'P', '`', 'l', '1', '`', 'p', '`', 'l', '2', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '6', '`', 'd', '1', '`', 'P', '`', 'r', '6', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '2', '`', 'P', '`', 'r', '1', '`', 'd', '1', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '9', '`', 'd', '1', '`', 'P', '`', 'r', '9', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'p', '`', 'r', '3', '`', 'P', '`', 'r', '3', '`', 'd', '1', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '3', '`', 'p', '`', 'l', '3', '`', 'P', '`', 'l', '9', '`', 'd', '1', '`'])

# %%
def interact_ser(_str, _ard):
    _ard.write(_str.encode())
    tmp = _ard.readline()
    print(tmp.decode())
    
if __name__ == "__main__":
    port = 'COM4'  # 변동가능
    ard = serial.Serial(port, 9600)
    time.sleep(3)

    for i in serial_deque:
        if list(pyautogui.position()) != [0, 0]:
            interact_ser(i, ard)

    ard.close()
# Out:
# p
#
# 0
#
# r
#
# 3
#
# 3
#
# P
#
# 0
#
# r
#
# 3
#
# 3
#
# p
#
# 0
#
# r
#
# 3
#
# 3
#
# P
#
# 0
#
# r
#
# 3
#
# 3
#
# p
#
# 0
#
# r
#
# 3
#
# 3
#
# P
#
# 0
#
# r
#
# 3
#
# 3
#
# p
#
# 0
#
# r
#
# 3
#
# 3
#
# d
#
# 1
#
# 1
#
# p
#
# 0
#
# l
#
# 3
#
# 3
#
# P
#
# 0
#
# l
#
# 3
#
# 3
#
# p
#
# 0
#
# l
#
# 3
#
# 3
#
# P
#
# 0
#
# l
#
# 3
#
# 3
#
# p
#
# 0
#
# l
#
# 3
#
# 3
#
# P
#
# 0
#
# l
#
# 3
#
# 3
#
# p
#
# 0
#
# l
#
# 3
#
# 3
#
# d
#
# 1
#
# 1
#
# p
#
# 0
#
# r
#
# 3
#
# 3
#
# P
#
# 0
#
# r
#
# 3
#
# 3
#
# p
#
# 0
#
# r
#
# 3
#
# 3
#
# P
#
# 0
#
# r
#
# 3
#
# 3
#
# p
#
# 0
#
# r
#
# 3
#
# 3
#
# P
#
# 0
#
# r
#
# 3
#
# 3
#
# p
#
# 0
#
# r
#
# 3
#
# 3
#
# d
#
# 1
#
# 1
#
# P
#
# 0
#
# l
#
# 3
#
# 3
#
# p
#
# 0
#
# l
#
# 3
#
# 3
#
# P
#
# 0
#
# l
#
# 3
#
# 3
#
# p
#
# 0
#
# l
#
# 3
#
# 3
#
# P
#
# 0
#
# l
#
# 3
#
# 3
#
# p
#
# 0
#
# l
#
# 3
#
# 3
#
# P
#
# 0
#
# l
#
# 3
#
# 3
#
# d
#
# 1
#
# 1
#
# P
#
# 0
#
# r
#
# 3
#
# 3
#
# p
#
# 0
#
# r
#
# 3
#
# 3
#
# P
#
# 0
#
# r
#
# 3
#
# 3
# ...
