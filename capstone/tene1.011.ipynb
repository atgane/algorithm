# %%
import pyautogui
import random
import time
import serial
import numpy as np
from queue import Queue
from IPython.display import clear_output

"""분포표를 누적 표로 바꿔줌"""
def pdtocd(m):
    n = []
    a = 0
    for i in range(len(m)):
        a = a + m[i][1]
        n.append([m[i][0], a])
    return n

"""누적표를 분포표로 바꿔줌"""
def cdtopd(m):
    n = []
    a = 0
    for i in range(len(m)):
        if i == 0:
            a = m[i][1]
        else:
            a = m[i][1] - m[i - 1][1]
        n.append([m[i][0], a])
    return n

"""누적표 m을 가져와서 f번째와 e번째 사이에 랜덤하게 st를 margin을 갖고 삽입"""
def insstr(m, st, f, e, margin):
    a = []
    test = cdtopd(m)
    for i in range(len(test)):
        if test[i][1] - 2 * margin > 0:
            if i == 0:
                test[i] = [0, m[i][1] - margin]
            else:
                test[i] = [m[i - 1][1] + margin, m[i][1] - margin]
        else:
            test[i] = 0
    b = []
    for i in range(f, e + 1):
        if test[i] != 0:
            b.append(test[i])
    c = np.random.randint(0, len(b))
    ret = m
    ret.append([st, np.random.uniform(b[c][0], b[c][1])])
    ret = cdsort(ret)
    return ret

"""누적표m에서 n번째에 간격 l로 s문자 넣기"""
def inscd(m, s, n, l):
    r = []
    j = 0
    for i in range(len(m) + 1):
        if i == n:
            r.append([s, np.random.uniform(m[i - 1][1] + l, m[i][1] - l)])
        else:
            r.append(m[j])
            j = j + 1
    return r

def partition(num1, a, ran):
    v = random.randint(1, a)
    lo = num1 / v
    out = []
    if v == 1:
        out.append(num1)
    else:
        c = 0
        ran_range = lo * ran / (v - 1)
        for i in range(v - 1):
            b = random.uniform(lo - ran_range, lo + ran_range)
            c += b
            out.append(b)
        out.append(num1 - c)
    return out

def part_2(num1, ran):
    out = []
    c = random.uniform((1 - ran) * num1 / 2, (1 + ran) * num1 / 2)
    out.append(c)
    out.append(num1 - c)
    return out

"""cd 큰거대로 정렬"""
def cdsort(m):
    k = []
    for i in range(len(m)):
        k.append(m[i][1])
    k.sort()
    n = []
    for i in range(len(m)):
        for j in range(len(m)):
            if k[i] == m[j][1]:
                n.append([m[j][0], m[j][1]])
                break
    return n

"""배열 큐로 바꾸기"""
def ArrayToQueue(m, q):
    for i in range(len(m)):
        q.put(m[i])

"""문자열입력받고 랜덤한 알파벳 하나 추출"""
def randstr(st):
    a = np.random.randint(0, len(st))
    return st[a]
        
def ser(ard, send, dtime):
    measure = time.time()
    while time.time() - measure < dtime:
        ard.write(send.encode('utf-8'))

def locask(img):
    try:
        return [img[0], img[1], img[2], img[3]]
    except:
        return [0, 0, 0, 0]

def bwtype(keyb, keyw):
    if keyb == [0, 0, 0, 0]:
        return 'w'
    elif keyw == [0, 0, 0, 0]:
        return 'b'
    else:
        return '0'

def clo(me, lo):
    try:
        return ((me[0] >= lo[0]) and (me[0] <= lo[2])) and ((me[1] >= lo[1]) and (me[1] <= lo[3]))
    except:
        return False

def findkeylo(key, lo):
    a = None
    while a == None:
        a = pyautogui.locateOnScreen(key, region=lo)
    if a != None:
        return a
    
def partition(num1, a, ran):
    v = random.randint(1, a)
    lo = num1 / v
    out = []
    if v == 1:
        out.append(num1)
    else:
        c = 0
        ran_range = lo * ran / (v - 1)
        for i in range(v - 1):
            b = random.uniform(lo - ran_range, lo + ran_range)
            c += b
            out.append(b)
        out.append(num1 - c)
    return out

def part_2(num1, ran):
    out = []
    c = random.uniform((1 - ran) * num1 / 2, (1 + ran) * num1 / 2)
    out.append(c)
    out.append(num1 - c)
    return out

class mac:
    def __init__(self):
        
        """
        important info image load initializer
        you must have image in your default folder
        It must be run once.
        """
        
        self.key2_img = 'key2.png'
        self.key3_img = 'key3.png'
        self.key4_img = 'key4.png'
        self.key6_img = 'key6.png'
        self.key7_img = 'key7.png'
        self.key9_img = 'key9.png'
        self.keyab_img = 'keyab.png'
        self.keyaw_img = 'keyaw.png'
        self.keye_img = 'keye.png'
        self.keyr_img = 'keyr.png'
        self.keyw_img = 'keyw.png'
        self.map_icon_img = 'map_icon.png'
        self.me_r_img = 'me_r.png'
        self.me_l_img = 'me_l.png'
        
        #self.key2 = pyautogui.locateOnScreen(self.key2_img, region=(700, 400, 1400, 800))
        #self.key3 = pyautogui.locateOnScreen(self.key3_img, region=(700, 400, 1400, 800))
        #self.key4 = pyautogui.locateOnScreen(self.key4_img, region=(700, 400, 1400, 800))
        #self.key6 = pyautogui.locateOnScreen(self.key6_img, region=(700, 400, 1400, 800))
        self.key7 = pyautogui.locateOnScreen(self.key7_img, region=(700, 400, 1400, 800))
        self.keyab = pyautogui.locateOnScreen(self.keyab_img, region=(700, 400, 1400, 800))
        self.keyaw = pyautogui.locateOnScreen(self.keyaw_img, region=(700, 400, 1400, 800))
        self.keye = pyautogui.locateOnScreen(self.keye_img, region=(700, 400, 1400, 800))
        self.keyr = pyautogui.locateOnScreen(self.keyr_img, region=(700, 400, 1400, 800))
        #self.keyw = pyautogui.locateOnScreen(self.keyw_img, region=(700, 400, 1400, 800))
        self.map_icon = pyautogui.locateOnScreen(self.map_icon_img, region=(0, 0, 300, 300))
        
        self.keyw = findkeylo(key=self.keyw_img, lo=(700, 400, 1400, 800))
        self.key2 = findkeylo(key=self.key2_img, lo=(700, 400, 1400, 800))
        self.key3 = findkeylo(key=self.key3_img, lo=(700, 400, 1400, 800))
        self.key4 = findkeylo(key=self.key4_img, lo=(700, 400, 1400, 800))
        self.key6 = findkeylo(key=self.key6_img, lo=(700, 400, 1400, 800))
        self.key9 = findkeylo(key=self.key9_img, lo=(700, 400, 1400, 800))
        
        self.key2 = locask(self.key2)
        self.key3 = locask(self.key3)
        self.key4 = locask(self.key4)
        self.key6 = locask(self.key6)
        self.key7 = locask(self.key7)
        self.key9 = locask(self.key9)
        self.keyab = locask(self.keyab)
        self.keyaw = locask(self.keyaw)
        self.keye = locask(self.keye)
        self.keyr = locask(self.keyr)
        self.keyw = locask(self.keyw)
        self.map_icon = locask(self.map_icon)
        
        self.t2 = [0, time.time() - 120]
        self.t3 = [0, time.time() - 180]
        self.t4 = [0, time.time() - 180]
        self.t6 = [0, time.time() - 180]
        self.t7 = [0, time.time() - 180]
        self.t9 = [0, time.time() - 120]
        
        print('self.key2')
        print(self.key2)
        print('self.key3')
        print(self.key3)
        print('self.key4')
        print(self.key4)
        print('self.key6')
        print(self.key6)
        print('self.key7')
        print(self.key7)
        print('self.key9')
        print(self.key9)
        print('self.keyab')
        print(self.keyab)
        print('self.keyaw')
        print(self.keyaw)
        print('self.keye')
        print(self.keye)
        print('self.keyr')
        print(self.keyr)
        print('self.keyw')
        print(self.keyw)
        print('self.map_icon')
        print(self.map_icon)
        
        self.initial_location = [self.map_icon[0], self.map_icon[1]]
        
        while self.initial_location == [0, 0]:
            print("initialized failed")
            print("restart")
            self.map_icon = pyautogui.locateOnScreen(self.map_icon_img, region=(0, 0, 300, 300))
            self.map_icon = locask(self.map_icon)
            self.initial_location = [self.map_icon[0], self.map_icon[1]]
            
        print("initial condition:",self.initial_location)
        
        self.m = []
        self.m1 = []
        self.m2 = []
        self.m3 = []
        self.m4 = []
        self.m5 = []
        self.m6 = []
        self.m7 = []
        self.m8 = []
        self.m9 = []
        
        """restrict location"""
        
        self.me_r_region = [self.initial_location[0] - 100, self.initial_location[1] + 50, 180, 80]
        self.me_l_region = [self.initial_location[0] - 100, self.initial_location[1] + 50, 180, 80]
        
        self.typea = bwtype(keyb=self.keyab, keyw=self.keyaw)
        
    def proc_serial(self, q2):
        
        while q2.qsize() != 0:
            volatile_data = q2.get()
            ser(self.ard, volatile_data[0], volatile_data[1])

    def proc_find_me(self, q1):
        
        """map info"""
        RANDOM_SEED1 = random.randint(-3, 3)
        RANDOM_SEED2 = random.randint(-6, 2)
        RANDOM_SEED3 = random.randint(-3, 5)
        RANDOM_SEED4 = random.randint(-10, 6)
        
        self.m = []
        self.m1 = [-53 + self.initial_location[0] + RANDOM_SEED2, 116 + self.initial_location[1], 
               69 + self.initial_location[0], 116 + self.initial_location[1]]
        self.m2 = [-41 + self.initial_location[0], 101 + self.initial_location[1], 
               58 + self.initial_location[0], 101 + self.initial_location[1]]
        self.m3 = [-83 + self.initial_location[0], 86 + self.initial_location[1], 
               -27 + self.initial_location[0] + RANDOM_SEED3, 86 + self.initial_location[1]]
        self.m4 = [-2 + self.initial_location[0], 78 + self.initial_location[1], 
               39 + self.initial_location[0] + RANDOM_SEED4, 78 + self.initial_location[1]]
        self.m5 = [-91 + self.initial_location[0], 69 + self.initial_location[1], 
               8 + self.initial_location[0], 69 + self.initial_location[1]]
        self.m6 = [-80 + self.initial_location[0] + RANDOM_SEED1, 116 + self.initial_location[1], 
               -54 + self.initial_location[0] + RANDOM_SEED2, 116 + self.initial_location[1]]
        self.m7 = [-93 + self.initial_location[0], 116 + self.initial_location[1], 
               -81 + self.initial_location[0] + RANDOM_SEED1, 116 + self.initial_location[1]]
        self.m8 = [-26 + self.initial_location[0] + RANDOM_SEED3, 86 + self.initial_location[1], 
               -4 + self.initial_location[0], 86 + self.initial_location[1]]
        self.m9 = [40 + self.initial_location[0] + RANDOM_SEED4, 78 + self.initial_location[1], 
               65 + self.initial_location[0], 78 + self.initial_location[1]]
        self.m.append(self.m1)
        self.m.append(self.m2)
        self.m.append(self.m3)
        self.m.append(self.m4)
        self.m.append(self.m5)
        self.m.append(self.m6)
        self.m.append(self.m7)
        self.m.append(self.m8)
        self.m.append(self.m9)
        
        """do not touch!!!"""
        """find character process"""
        _state = q1.qsize()
        
        intime = time.time()
        while q1.qsize() <= _state:
            me = []
            me = pyautogui.locateOnScreen(self.me_r_img, region=self.me_r_region)
            if me == None:
                me = pyautogui.locateOnScreen(self.me_l_img, region=self.me_l_region)
        
            for i in range(len(self.m)):
                if clo(me, self.m[i]):
                    if i + 1 == 2:
                        if pyautogui.locateOnScreen(self.keyw_img, region=self.keyw):
                            q1.put('21')
                            print('21')
                        elif pyautogui.locateOnScreen(self.keye_img, region=self.keye):
                            q1.put('22')
                            print('22')
                        else:
                            q1.put(str(i + 1))
                            print(str(i + 1))
                    elif i + 1 == 3:
                        if random.randint(0, 3) == 0:
                            q1.put('31')
                            print('31')
                        else:
                            q1.put(str(i + 1))
                            print(str(i + 1))
                    else:
                        q1.put(str(i + 1))
                        print(str(i + 1))
            if time.time() - intime > random.uniform(2, 3):
                q1.put('1')
        
            
    def proc_find_buf(self, q1):
        
        """do not touch!!!"""
        """find buf process"""
        try:
            if time.time() - self.t2[1] > 110 and pyautogui.locateOnScreen(self.key2_img, region=self.key2):
                q1.put('key2')
                print('key2')
                self.t2[0] = 0
            elif self.t2[0] < 3:
                self.t2[0] += 1
            elif self.t2[0] == 3:
                self.t2[1] = time.time()
                self.t2[0] = 4
        except:
            _ = 1
        try:
            if time.time() - self.t3[1] > 170 and pyautogui.locateOnScreen(self.key3_img, region=self.key3):
                q1.put('key3')
                print('key3')
                self.t3[0] = 0
            elif self.t3[0] < 3:
                self.t3[0] += 1
            elif self.t3[0] == 3:
                self.t3[1] = time.time()
                self.t3[0] = 4
        except:
            _ = 1
        try:
            if time.time() - self.t4[1] > 170 and pyautogui.locateOnScreen(self.key4_img, region=self.key4):
                q1.put('key4')
                print('key4')
                self.t4[0] = 0
            elif self.t4[0] < 3:
                self.t4[0] += 1
            elif self.t4[0] == 3:
                self.t4[1] = time.time()
                self.t4[0] = 4
        except:
            _ = 1
        try:
            if time.time() - self.t6[1] > 170 and pyautogui.locateOnScreen(self.key6_img, region=self.key6):
                q1.put('key6')
                print('key6')
                self.t6[0] = 0
            elif self.t6[0] < 3:
                self.t6[0] += 1
            elif self.t6[0] == 3:
                self.t6[1] = time.time()
                self.t6[0] = 4
        except:
            _ = 1
        try:
            if time.time() - self.t9[1] > 110 and pyautogui.locateOnScreen(self.key9_img, region=self.key9):
                q1.put('key9')
                print('key9')
                self.t9[0] = 0
            elif self.t9[0] < 3:
                self.t9[0] += 1
            elif self.t9[0] == 3:
                self.t9[1] = time.time()
                self.t9[0] = 4
        except:
            _ = 1
        if self.typea == 'b':
            try:
                if pyautogui.locateOnScreen(self.keyab_img, region=self.keyab):
                    q1.put('keyab')
                    print('keyab')
            except:
                _ = 1
        elif self.typea == 'w':
            try:
                if pyautogui.locateOnScreen(self.keyaw_img, region=self.keyaw):
                    q1.put('keyaw')
                    print('keyaw')
            except:
                _ = 1
        
        
    def proc_queue(self, q1, q2):
        
        """Editable."""
        """skill queue process"""
        
        while q1.qsize() != 0:
            volatile_val = q1.get()
            if volatile_val == 'key2':
                test = []
                a = partition(0.6 + random.uniform(0.05, 0.095), random.randint(1, 1), random.uniform(0.4, 0.7))
                for i in range(len(a)):
                    b = part_2(a[i], random.uniform(0.4, 0.7))
                    test.append(['2', b[0]])
                    test.append(['@', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                s = randstr('hk')
                if np. random.randint(0, 2) == 1:
                    cdtest = insstr(cdtest, s, 1, 1, 0.01)
                    cdtest = insstr(cdtest, s.upper(), 2, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == 'key3':
                test = []
                a = partition(0.6 + random.uniform(0.05, 0.095), random.randint(1, 3), random.uniform(0.4, 0.7))
                for i in range(len(a)):
                    b = part_2(a[i], random.uniform(0.4, 0.7))
                    test.append(['3', b[0]])
                    test.append(['#', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                s = randstr('hk')
                if np. random.randint(0, 2) == 1:
                    cdtest = insstr(cdtest, s, 1, 1, 0.01)
                    cdtest = insstr(cdtest, s.upper(), 2, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == 'key4':
                test = []
                a = partition(0.6 + random.uniform(0.05, 0.095), random.randint(1, 3), random.uniform(0.4, 0.7))
                for i in range(len(a)):
                    b = part_2(a[i], random.uniform(0.4, 0.7))
                    test.append(['4', b[0]])
                    test.append(['$', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                s = randstr('hk')
                if np. random.randint(0, 2) == 1:
                    cdtest = insstr(cdtest, s, 1, 1, 0.01)
                    cdtest = insstr(cdtest, s.upper(), 2, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == 'key6':
                test = []
                a = partition(0.6 + random.uniform(0.05, 0.095), random.randint(1, 3), random.uniform(0.4, 0.7))
                for i in range(len(a)):
                    b = part_2(a[i], random.uniform(0.4, 0.7))
                    test.append(['6', b[0]])
                    test.append(['^', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                s = randstr('hk')
                if np. random.randint(0, 2) == 1:
                    cdtest = insstr(cdtest, s, 1, 1, 0.01)
                    cdtest = insstr(cdtest, s.upper(), 2, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == 'key9':
                test = []
                a = partition(0.6 + random.uniform(0.05, 0.095), random.randint(1, 3), random.uniform(0.4, 0.7))
                for i in range(len(a)):
                    b = part_2(a[i], random.uniform(0.4, 0.7))
                    test.append(['9', b[0]])
                    test.append(['(', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                s = randstr('hk')
                if np. random.randint(0, 2) == 1:
                    cdtest = insstr(cdtest, s, 1, 1, 0.01)
                    cdtest = insstr(cdtest, s.upper(), 2, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == 'keyab':
                test = []
                a = partition(0.55 + random.uniform(0.05, 0.095), random.randint(1, 3), random.uniform(0.4, 0.7))
                for i in range(len(a)):
                    b = part_2(a[i], random.uniform(0.4, 0.7))
                    test.append(['a', b[0]])
                    test.append(['A', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                s = randstr('hk')
                if np. random.randint(0, 2) == 1:
                    cdtest = insstr(cdtest, s, 1, 1, 0.01)
                    cdtest = insstr(cdtest, s.upper(), 2, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == 'keyaw':
                test = []
                a = partition(0.55 + random.uniform(0.05, 0.095), random.randint(1, 3), random.uniform(0.4, 0.7))
                for i in range(len(a)):
                    b = part_2(a[i], random.uniform(0.4, 0.7))
                    test.append(['a', b[0]])
                    test.append(['A', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                s = randstr('hk')
                if np. random.randint(0, 2) == 1:
                    cdtest = insstr(cdtest, s, 1, 1, 0.01)
                    cdtest = insstr(cdtest, s.upper(), 2, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == '1':
                test = []
                test.append(['h', np.random.normal(0.07, 0.01)])
                test.append(['H', np.random.normal(0.065, 0.01)])
                test.append(['x', np.random.normal(0.085, 0.01)])
                test.append(['h', np.random.normal(0.08, 0.01)])
                test.append(['H', np.random.normal(0.065, 0.01)])
                test.append(['h', np.random.normal(0.07, 0.01)])
                c = partition(0.2 + random.uniform(0.05, 0.095), 3, random.uniform(0.4, 0.7))
                for i in range(len(c)):
                    b = part_2(c[i], random.uniform(0.4, 0.7))
                    test.append(['z', b[0]])
                    test.append(['Z', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                cdtest = insstr(cdtest, 'H', 6, len(cdtest) - 1, 0.01)
                cdtest = insstr(cdtest, 'X', 3, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == '2':
                test = []
                test.append(['k', np.random.normal(0.07, 0.01)])
                test.append(['K', np.random.normal(0.065, 0.01)])
                test.append(['x', np.random.normal(0.085, 0.01)])
                test.append(['k', np.random.normal(0.08, 0.01)])
                test.append(['K', np.random.normal(0.065, 0.01)])
                test.append(['k', np.random.normal(0.07, 0.01)])
                c = partition(0.2 + random.uniform(0.05, 0.095), 3, random.uniform(0.4, 0.7))
                for i in range(len(c)):
                    b = part_2(c[i], random.uniform(0.4, 0.7))
                    test.append(['z', b[0]])
                    test.append(['Z', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                cdtest = insstr(cdtest, 'K', 6, len(cdtest) - 1, 0.01)
                cdtest = insstr(cdtest, 'X', 3, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == '21':
                q2.put(['w', np.random.normal(0.07, 0.01)])
                q2.put(['W', np.random.normal(0.7, 0.1)])
            
            elif volatile_val == '22':
                q2.put(['0', np.random.normal(0.17, 0.20)])
                q2.put(['e', np.random.normal(0.07, 0.1)])
                q2.put(['E', np.random.normal(0.07, 0.1)])
                q2.put(['r', np.random.normal(0.07, 0.1)])
                q2.put(['R', np.random.normal(0.07, 0.1)])
            
            elif volatile_val == '3':
                test = []
                test.append(['k', np.random.normal(0.07, 0.01)])
                test.append(['K', np.random.normal(0.065, 0.01)])
                test.append(['x', np.random.normal(0.085, 0.01)])
                test.append(['k', np.random.normal(0.08, 0.01)])
                test.append(['K', np.random.normal(0.065, 0.01)])
                test.append(['k', np.random.normal(0.07, 0.01)])
                c = partition(0.2 + random.uniform(0.05, 0.095), 3, random.uniform(0.4, 0.7))
                for i in range(len(c)):
                    b = part_2(c[i], random.uniform(0.4, 0.7))
                    test.append(['z', b[0]])
                    test.append(['Z', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                cdtest = insstr(cdtest, 'K', 6, len(cdtest) - 1, 0.01)
                cdtest = insstr(cdtest, 'X', 3, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == '31':
                q2.put(['x', 0.029 + random.uniform(0, 0.025)])
                q2.put(['X', 0.036 + random.uniform(0, 0.025)])
                q2.put(['u', 0.04 + random.uniform(0, 0.025)])
                q2.put(['U', 0.032 + random.uniform(0, 0.025)])
                q2.put(['u', 0.035 + random.uniform(0, 0.025)])
                q2.put(['U', 0.033 + random.uniform(0, 0.025)])
            
            elif volatile_val == '4':
                test = []
                test.append(['k', np.random.normal(0.07, 0.01)])
                test.append(['K', np.random.normal(0.065, 0.01)])
                test.append(['x', np.random.normal(0.085, 0.01)])
                test.append(['k', np.random.normal(0.08, 0.01)])
                test.append(['K', np.random.normal(0.065, 0.01)])
                test.append(['k', np.random.normal(0.07, 0.01)])
                c = partition(0.2 + random.uniform(0.05, 0.095), 3, random.uniform(0.4, 0.7))
                for i in range(len(c)):
                    b = part_2(c[i], random.uniform(0.4, 0.7))
                    test.append(['z', b[0]])
                    test.append(['Z', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                cdtest = insstr(cdtest, 'K', 6, len(cdtest) - 1, 0.01)
                cdtest = insstr(cdtest, 'X', 3, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == '5':
                test = []
                test.append(['k', np.random.normal(0.07, 0.01)])
                test.append(['K', np.random.normal(0.065, 0.01)])
                test.append(['x', np.random.normal(0.085, 0.01)])
                test.append(['k', np.random.normal(0.08, 0.01)])
                test.append(['K', np.random.normal(0.065, 0.01)])
                test.append(['k', np.random.normal(0.07, 0.01)])
                c = partition(0.2 + random.uniform(0.05, 0.095), 3, random.uniform(0.4, 0.7))
                for i in range(len(c)):
                    b = part_2(c[i], random.uniform(0.4, 0.7))
                    test.append(['z', b[0]])
                    test.append(['Z', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                cdtest = insstr(cdtest, 'K', 6, len(cdtest) - 1, 0.01)
                cdtest = insstr(cdtest, 'X', 3, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == '6':
                q2.put(['[', 0.025 + random.uniform(0, 0.025)])
                q2.put(['{', 0.035 + random.uniform(0, 0.025)])
                q2.put(['c', 0.02 + random.uniform(0, 0.025)])
                q2.put(['C', 0.035 + random.uniform(0, 0.025)])
                q2.put(['k', 0.028 + random.uniform(0, 0.025)])
                q2.put(['x', 0.029 + random.uniform(0, 0.025)])
                q2.put(['X', 0.036 + random.uniform(0, 0.025)])
                q2.put(['u', 0.04 + random.uniform(0, 0.025)])
                q2.put(['U', 0.032 + random.uniform(0, 0.025)])
                q2.put(['u', 0.035 + random.uniform(0, 0.025)])
                q2.put(['U', 0.033 + random.uniform(0, 0.025)])
                q2.put(['K', 0.031 + random.uniform(0, 0.025)])
            
            elif volatile_val == '7':
                test = []
                test.append(['k', np.random.normal(0.07, 0.01)])
                test.append(['K', np.random.normal(0.065, 0.01)])
                test.append(['x', np.random.normal(0.085, 0.01)])
                test.append(['k', np.random.normal(0.08, 0.01)])
                test.append(['K', np.random.normal(0.065, 0.01)])
                test.append(['k', np.random.normal(0.07, 0.01)])
                c = partition(0.2 + random.uniform(0.05, 0.095), 3, random.uniform(0.4, 0.7))
                for i in range(len(c)):
                    b = part_2(c[i], random.uniform(0.4, 0.7))
                    test.append(['z', b[0]])
                    test.append(['Z', b[1]])
                test.append(['0', 0.021])
                cdtest = pdtocd(test)
                cdtest = insstr(cdtest, 'K', 6, len(cdtest) - 1, 0.01)
                cdtest = insstr(cdtest, 'X', 3, len(cdtest) - 1, 0.01)
                pdtest = cdtopd(cdtest)
                ArrayToQueue(pdtest, q2)
                
            elif volatile_val == '8':
                q2.put(['k', 0.012 + random.uniform(0, 0.025)])
                q2.put(['K', 0.025 + random.uniform(0, 0.025)])
                q2.put(['j', 0.032 + random.uniform(0, 0.025)])
                q2.put(['x', 0.032 + random.uniform(0, 0.025)])
                q2.put(['X', 0.1 + random.uniform(0, 0.025)])
                q2.put(['J', 0.07 + random.uniform(0, 0.025)])
                
            elif volatile_val == '9':
                q2.put(['k', 0.03 + random.uniform(0, 0.025)])
                q2.put(['K', 0.07 + random.uniform(0, 0.025)])
                q2.put(['j', 0.032 + random.uniform(0, 0.025)])
                q2.put(['x', 0.032 + random.uniform(0, 0.025)])
                q2.put(['X', 0.1 + random.uniform(0, 0.025)])
                q2.put(['J', 0.07 + random.uniform(0, 0.025)])
                
            
if __name__ == "__main__":
    
    """setup line"""
    
    port = "COM3"
    ard = serial.Serial(port, 9600)
    
    p1t = time.time()
    while time.time() - p1t < 1:
        _ = 1
    tene = mac()
    main_queue = Queue()
    serial_queue = Queue()
# Out:
# self.key2
# [990, 731, 27, 28]
# self.key3
# [1025, 731, 28, 28]
# self.key4
# [1060, 731, 28, 28]
# self.key6
# [1130, 731, 28, 28]
# self.key7
# [1165, 731, 28, 28]
# self.key9
# [1236, 732, 26, 26]
# self.keyab
# [815, 766, 28, 28]
# self.keyaw
# [0, 0, 0, 0]
# self.keye
# [885, 731, 28, 28]
# self.keyr
# [920, 731, 28, 28]
# self.keyw
# [850, 731, 28, 28]
# self.map_icon
# [110, 48, 9, 6]
# initial condition: [110, 48]

# %%
if __name__ == '__main__':
    while True:
        clear_output(wait=True)
        tot_time = time.time()
        
        """loop line"""
        tene.proc_find_buf(main_queue)
        tene.proc_find_me(main_queue)
        tene.proc_queue(main_queue, serial_queue)
        while serial_queue.qsize() != 0:
            try:
                volatile_data = serial_queue.get()
                if ard.writable():
                    ser(ard, volatile_data[0], volatile_data[1])
            except:
                ard.close()
                print('close port')
                for i in range(20):
                    clear_output(wait=True)
                    time.sleep(1)
                    print(20 - i)
                ard.open()
        print('calculation time:1', time.time() - tot_time)
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-3-5315291595c3> in <module>
#      13                 if ard.writable():
# ---> 14                     ser(ard, volatile_data[0], volatile_data[1])
#      15             except:
#
# <ipython-input-1-85c1949ad166> in ser(ard, send, dtime)
#     113     while time.time() - measure < dtime:
# --> 114         ard.write(send.encode('utf-8'))
#     115
#
# ~\anaconda3\lib\site-packages\serial\serialwin32.py in write(self, data)
#     314                 if not success and win32.GetLastError() not in (win32.ERROR_SUCCESS, win32.ERROR_IO_PENDING):
# --> 315                     raise SerialException("WriteFile failed ({!r})".format(ctypes.WinError()))
#     316
#
# SerialException: WriteFile failed (PermissionError(13, '장치가 명령을 인식하지 않습니다.', None, 22))
#
# During handling of the above exception, another exception occurred:
#
# ...
